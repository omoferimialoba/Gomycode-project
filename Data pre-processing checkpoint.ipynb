# %%
#  What You're Aiming For

#  In this checkpoint, we are going to work on the billing history of the Tunisian electricity and gas company and apply what you learned in pre-processing chapter.

#  Dataset description : 

#  The provided dataset contains the billing history of the Tunisian electricity and gas company's customers from 2005 to 2019.

#   Dataset link
#  https://drive.google.com/file/d/1DVFNq8Gsf9wFZznGafhykVmVHLvAclGo/view
    

    
#  Instructions

# Load the dataset, display the ten first lines, store the results in a variable called 'client_0_bills'.
#  What is the data type of the 'client_0_bills' variable ?
#  Display the general information of the dataset and try to answer the following questions : 
#  How many rows and columns do we have in this dataset ?
#  How many categorical features are present in the dataset ?
#  How much memory space does the dataset consume ?
#  Inspect the dataset for potential missing values.
#  Select your strategy to handle missing values, and tell us why you had made that choice.
#  Run a descriptive analysis on numeric features (columns).
#  Select the bills records for the client with an id ='train_Client_0', using 2 methods.
#  Transform the 'counter_type' feature to a numeric variable using the encoder of your choice.
#  Delete the 'counter_statue' feature from the Dataframe

# %%
import pandas as pd

# %%
#1 Load the dataset, display the ten first lines, store the results in a variable called 'client_0_bills'
client_0_bills = pd.read_csv(r"STEG_BILLING_HISTORY.csv", low_memory=False)
client_0_bills
# Out:
#                   client_id invoice_date  tarif_type  counter_number  \
# 0            train_Client_0   2014-03-24          11       1335667.0
# 1            train_Client_0   2013-03-29          11       1335667.0
# 2            train_Client_0   2015-03-23          11       1335667.0
# 3            train_Client_0   2015-07-13          11       1335667.0
# 4            train_Client_0   2016-11-17          11       1335667.0
# ...                     ...          ...         ...             ...
# 4476744  train_Client_99998   2005-08-19          10       1253571.0
# 4476745  train_Client_99998   2005-12-19          10       1253571.0
# 4476746  train_Client_99999   1996-09-25          11        560948.0
# 4476747  train_Client_99999   1996-05-28          11        560948.0
# 4476748  train_Client_99999   1996-01-25          11        560948.0
#
#         counter_statue  counter_code  reading_remarque  counter_coefficient  \
# ...

# %%
#1 Load the dataset, display the ten first lines, store the results in a variable called 'client_0_bills'
client_0_bills.head(10)
# Out:
#         client_id invoice_date  tarif_type  counter_number counter_statue  \
# 0  train_Client_0   2014-03-24          11       1335667.0              0
# 1  train_Client_0   2013-03-29          11       1335667.0              0
# 2  train_Client_0   2015-03-23          11       1335667.0              0
# 3  train_Client_0   2015-07-13          11       1335667.0              0
# 4  train_Client_0   2016-11-17          11       1335667.0              0
# 5  train_Client_0   2017-07-17          11       1335667.0              0
# 6  train_Client_0   2018-12-07          11       1335667.0              0
# 7  train_Client_0   2019-03-19          11       1335667.0              0
# 8  train_Client_0   2011-07-22          11       1335667.0              0
# 9  train_Client_0   2011-11-22          11       1335667.0              0
#
#    counter_code  reading_remarque  counter_coefficient  consommation_level_1  \
# ...

# %%
client_0_bills.client_id.unique(),train_Client_1
# Out:
# array(['train_Client_0', 'train_Client_1', 'train_Client_10', ...,
#        'train_Client_99997', 'train_Client_99998', 'train_Client_99999'],
#       dtype=object)

# %%
#client_0_bills[(client_0_bills.client_id =='train_Client_1') | (client_0_bills.client_id =='train_Client_0') ]
#client_0_bills.query("client_id=='train_Client_1'| client_id== 'train_Client_0'")                                                             

# Assuming 'client_0_bills' is your DataFrame
#filtered_bills = client_0_bills[(client_0_bills['client_id'] == 'train_Client_1') | (client_0_bills['client_id'] == 'train_Client_0')]
#filtered_billsfiltered_bills = client_0_bills.query(
# Out:
#          client_id invoice_date  tarif_type  counter_number counter_statue  \
# 0   train_Client_0   2014-03-24          11       1335667.0              0
# 1   train_Client_0   2013-03-29          11       1335667.0              0
# 2   train_Client_0   2015-03-23          11       1335667.0              0
# 3   train_Client_0   2015-07-13          11       1335667.0              0
# 4   train_Client_0   2016-11-17          11       1335667.0              0
# ..             ...          ...         ...             ...            ...
# 67  train_Client_1   2015-04-02          11        678902.0              0
# 68  train_Client_1   2014-09-25          11        678902.0              0
# 69  train_Client_1   2013-01-10          11        678902.0              0
# 70  train_Client_1   2005-10-19          11        678902.0              0
# 71  train_Client_1   2013-05-31          11        678902.0              0
#
# ...

# %%
 #2 What is the data type of the 'client_0_bills' variable ?
print(type(client_0_bills))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
#3. Display the general information of the dataset and try to answer the following questions : 
client_0_bills.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4476749 entries, 0 to 4476748
# Data columns (total 16 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   client_id             object
#  1   invoice_date          object
#  2   tarif_type            int64
#  3   counter_number        float64
#  4   counter_statue        object
#  5   counter_code          int64
#  6   reading_remarque      float64
#  7   counter_coefficient   int64
#  8   consommation_level_1  int64
#  9   consommation_level_2  int64
#  10  consommation_level_3  int64
#  11  consommation_level_4  int64
#  12  old_index             int64
#  13  new_index             int64
#  14  months_number         int64
#  15  counter_type          object
# dtypes: float64(2), int64(10), object(4)
# memory usage: 546.5+ MB

# %%
#3A  How many rows and columns do we have in this dataset ?
Row_number, Column_number = client_0_bills.shape
print(" The number of rows and columns are" , Row_number, "and" ,Column_number, "respectively")
# Out:
#  The number of rows and columns are 4476749 and 16 respectively

# %%
#3b  How many categorical features are present in the dataset ?
categorical = client_0_bills.select_dtypes('object').head(2)
display(categorical)
categorical1 = client_0_bills.select_dtypes(include = 'object').head(2)
display(categorical1)
# Out:
#         client_id invoice_date counter_statue counter_type
# 0  train_Client_0   2014-03-24              0         ELEC
# 1  train_Client_0   2013-03-29              0         ELEC
#         client_id invoice_date counter_statue counter_type
# 0  train_Client_0   2014-03-24              0         ELEC
# 1  train_Client_0   2013-03-29              0         ELEC

# %%
#3c How much memory space does the dataset consume 
client_0_bills.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4476749 entries, 0 to 4476748
# Data columns (total 16 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   client_id             object
#  1   invoice_date          object
#  2   tarif_type            int64
#  3   counter_number        float64
#  4   counter_statue        object
#  5   counter_code          int64
#  6   reading_remarque      float64
#  7   counter_coefficient   int64
#  8   consommation_level_1  int64
#  9   consommation_level_2  int64
#  10  consommation_level_3  int64
#  11  consommation_level_4  int64
#  12  old_index             int64
#  13  new_index             int64
#  14  months_number         int64
#  15  counter_type          object
# dtypes: float64(2), int64(10), object(4)
# memory usage: 1.5 GB

# %%
#3c How much memory space does the dataset consume 
memory_usage = client_0_bills.memory_usage(deep=True).sum()
memory_usage
# Out:
# 1597611090

# %%
#4Inspect the dataset for potential missing values
print(client_0_bills.isna().sum())
missing_counts = client_0_bills.isna().sum() / len(client_0_bills) * 100
print('\n')
print('\n')
print('\n')
print(missing_counts)
# Out:
# client_id                  0
# invoice_date               0
# tarif_type                 0
# counter_number            48
# counter_statue             0
# counter_code               0
# reading_remarque        4531
# counter_coefficient        0
# consommation_level_1       0
# consommation_level_2       0
# consommation_level_3       0
# consommation_level_4       0
# old_index                  0
# new_index                  0
# months_number              0
# counter_type               0
# dtype: int64
#
#
#
#
#
#
# client_id               0.000000
# invoice_date            0.000000
# tarif_type              0.000000
# counter_number          0.001072
# counter_statue          0.000000
# counter_code            0.000000
# reading_remarque        0.101212
# counter_coefficient     0.000000
# consommation_level_1    0.000000
# consommation_level_2    0.000000
# consommation_level_3    0.000000
# consommation_level_4    0.000000
# old_index               0.000000
# ...

# %% [markdown]
# QUESTION 5 Select your strategy to handle missing values, and tell us why you had made that choice.
# To decide on a strategy for handling missing values using the output of client_0_bills.isna().sum(), consider these concise steps:
#
# Evaluate Missing Data: Check the percentage of missing values per column (missing_counts = client_0_bills.isna().sum() / len(client_0_bills) * 100).
# Low Missing Data (<5%): Remove rows (client_0_bills.dropna(inplace=True)).
# Moderate Missing Data (5%-30%): Impute using median for numerical data and mode for categorical data (client_0_bills.fillna({'num_col': client_0_bills['num_col'].median(), 'cat_col': client_0_bills['cat_col'].mode()[0]}, inplace=True)).
# High Missing Data (>05%): Consider advanced imputation techniques or dropping the column if it’s not crucial (client_0_bills.drop(columns=['high_missing_col'], inplace=True)).

# %%
# 6Run a descriptive analysis on numeric features (columns).
client_0_bills.describe()
# Out:
#          tarif_type  counter_number  counter_code  reading_remarque  \
# count  4.476749e+06    4.476701e+06  4.476749e+06      4.472218e+06
# mean   2.012804e+01    1.230595e+11  1.724884e+02      7.321713e+00
# std    1.347256e+01    1.657276e+12  1.338871e+02      1.571859e+00
# min    8.000000e+00    0.000000e+00  0.000000e+00      5.000000e+00
# 25%    1.100000e+01    1.211080e+05  5.000000e+00      6.000000e+00
# 50%    1.100000e+01    4.945610e+05  2.030000e+02      8.000000e+00
# 75%    4.000000e+01    1.115161e+06  2.070000e+02      9.000000e+00
# max    4.500000e+01    2.798115e+13  6.000000e+02      4.130000e+02
#
#        counter_coefficient  consommation_level_1  consommation_level_2  \
# count         4.476749e+06          4.476749e+06          4.476749e+06
# mean          1.003040e+00          4.109795e+02          1.093225e+02
# std           3.083466e-01          7.573080e+02          1.220123e+03
# ...

# %%
# 7Select the bills records for the client with an id ='train_Client_0', using 2 methods.
client_0_bills[client_0_bills['client_id'] =='train_Client_0']
# method two
client_0_bills.loc[client_0_bills['client_id'] =='train_Client_0']
#Method three
selected_records = client_0_bills.query("client_id == 'train_Client_0'")
selected_records
# Out:
#          client_id invoice_date  tarif_type  counter_number counter_statue  \
# 0   train_Client_0   2014-03-24          11       1335667.0              0
# 1   train_Client_0   2013-03-29          11       1335667.0              0
# 2   train_Client_0   2015-03-23          11       1335667.0              0
# 3   train_Client_0   2015-07-13          11       1335667.0              0
# 4   train_Client_0   2016-11-17          11       1335667.0              0
# 5   train_Client_0   2017-07-17          11       1335667.0              0
# 6   train_Client_0   2018-12-07          11       1335667.0              0
# 7   train_Client_0   2019-03-19          11       1335667.0              0
# 8   train_Client_0   2011-07-22          11       1335667.0              0
# 9   train_Client_0   2011-11-22          11       1335667.0              0
# 10  train_Client_0   2008-11-25          11       1335667.0              0
# ...

# %%
#8Transform the 'counter_type' feature to a numeric variable using the encoder of your choice.
from sklearn.preprocessing import LabelEncoder
data = {'counter_type': ['ELEC']}
df = pd.DataFrame(data)
label_encoder = LabelEncoder()
df['counter_type_numeric'] = label_encoder.fit_transform(df['counter_type'])
print(df)
# Out:
#   counter_type  counter_type_numeric
# 0         ELEC                     0

# %%
#9 Delete the 'counter_statue' feature from the Dataframe
data= {'counter_statue': [0]}
df = pd.DataFrame(data)
df = df.drop('counter_statue', axis=1)
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: [0]
