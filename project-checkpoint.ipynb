# %%
# # MoneyGen is a modern company built to enhance the economy of Nigeria. 
# The company has competitors in the market which include who wants to be a millionaire, bet9ja, Baba ijebu etc. 
# The company wants to employ the use of python programming language to overtake the other companies in the market.
# As a pythoneer or pythonista, develop a program that has the following functionalities. 

# # Create a class that would be taking in the profile of a player e.g name, gender, age and state of origin. 
# Create a method that can randomly pick 10 questions from a database and return the question to the player, once the player picks the correct option,
# store the results of the score and print the final result of the player.
# MoneyGen wants to store the data of every player and their scores for future purposes,
# create a dictionary or list that can store these results and show the business owner later what each person scored. 

# # Note that there should be only 10 questions in the quiz and you can store more than 5 unique players data.

# %%
# jacob

result = 0

class Player:
    
    def __init__(self, name, gender, age, state):
        self.name = name
        self.gender = gender
        self.age = age
        self.state = state
        
    def Questions(self):
        print('wwww')
        print("\n")
        
        quiz_questions = {
            1: "Is MoneyGen's core activity 'Finance'? Yes or No.",
            2: "Does MoneyGen offer educational resources? Yes or No.",
            3: "Is MoneyGen involved in gambling? Yes or No.",
            4: "Can entrepreneurs benefit from MoneyGen? Yes or No.",
            5: "Does MoneyGen operate nationwide? Yes or No.",
            6: "Is MoneyGen technology-driven? Yes or No.",
            7: "Does MoneyGen support investments? Yes or No.",
            8: "Are MoneyGen's services digital? Yes or No.",
            9: "Does MoneyGen promote savings? Yes or No.",
            10: "Is MoneyGen's platform secure? Yes or No."
        }
        
        for question in quiz_questions.values():
            print(question)
            
            answer = input("Enter answer: ").lower()
            if answer == "yes":
                global result
                result += 2
            else:
                result = result
            print(f"Your current score is: {result}")


player1 = Player("John", "Male", 25, "California")
player1.Questions()

# %%
import random
Player_name = []
class Player:
    
    def __init__(self):
        name = input('Enter Your Name: ')
        self.name = name
        self.gender = gender
        self.age = age
        self.state = state
        Player_name.append(self.name)
        Player_name.append(self.gender)
        
    def Questions(self):
        quiz_questions = {1: "Is MoneyGen's core activity 'Finance'? Yes or No .",
        2: "Does MoneyGen offer educational resources? Yes  or No ",
        3: "Is MoneyGen involved in gambling?  Yes  or No ",
        4: "Can entrepreneurs benefit from MoneyGen? Yes  or No ",
        5: "Does MoneyGen operate nationwide? Yes  or No ",
        6:  "Is MoneyGen technology-driven? Yes  or No ",
        7: "Does MoneyGen support investments? Yes/No",
        8: "Are MoneyGen's services digital? Yes/No ",
        9: "Does MoneyGen promote savings? Yes/No ",
        10: "Is MoneyGen's platform secure? Yes/No "}
        
        result = 0
        Question2 = random.sample(sorted(quiz_questions.values()),10)
       
        
        for question in  Question2 :
            print(f'{question}')
            
            answer = input("enter answer  " ).lower()
        
            if answer == "yes":
                result += 2
        Player_name.append(result)

        print(f"Your score is equal to {result}")
        player1 = Player()
        player1.Questions()
        print(Player_name)

# %%
import random
Player_name = []
class Player:
    
    def __init__(self):
        name = input('Enter Your Name: ')
        Player_name.append(name)
        
    def Questions(self):
        quiz_questions = {1: "Is MoneyGen's core activity 'Finance'? Yes or No .",
        2: "Does MoneyGen offer educational resources? Yes  or No ",
        3: "Is MoneyGen involved in gambling?  Yes  or No ",
        4: "Can entrepreneurs benefit from MoneyGen? Yes  or No ",
        5: "Does MoneyGen operate nationwide? Yes  or No ",
        6:  "Is MoneyGen technology-driven? Yes  or No ",
        7: "Does MoneyGen support investments? Yes/No",
        8: "Are MoneyGen's services digital? Yes/No ",
        9: "Does MoneyGen promote savings? Yes/No ",
        10: "Is MoneyGen's platform secure? Yes/No "}
        
        result = 0
        Question2 = random.sample(sorted(quiz_questions.values()),10)
       
        
        for question in  Question2 :
            print(f'{question}')
            
            answer = input("enter answer  " ).lower()
        
            if answer == "yes":
                result += 2
        Player_name.append(result)

        print(f"{, Your score is equal to {result}")
player1 = Player()
player1.Questions()
print(Player_name)

# %%
Player_name
print(Player_name)

# %%
player1 = Player("Don", "Male", 25, "California")
player1.Questions()

# %%
# nested dictionary  learning
alienss = [
    {'color': 'green', 'points': 5},
    {'color': 'yellow', 'points': 10},
    {'color': 'red', 'points': 15}
]

alien_points = []  # Create an empty list to store points

for alien in alienss:
    alien_points.append(alien.get("points"))

print(alien_points)

# %%
# nested dictionary  learning
alienss =[ {'color': 'green', 'points': 5},
 {'color': 'yellow', 'points': 10},
 {'color': 'red', 'points': 15}]

for alien in alienss:
    alien_key =  alien.get("points")
    print(alien_key)

# %%
# nested dictionary  learning
alien_0 = {'color': 'green', 'points': 5}
alien_1 = {'color': 'yellow', 'points': 10}
alien_2 = {'color': 'red', 'points': 15}

aliens = [alien_0, alien_1, alien_2]
for alien in aliens:
    print(alien)

# %%
# quiz application
score = 0
questions = [ {"Question": "A square has ____ sides",  "answer": "5"}, 
               {"Question": "how many leg does ahuman being have  ", "answer": "4"},
            {"Question": "How many continent are there in planet earth", "answer": 7  }
            ]

for Quiz in questions:
    questiontext = Quiz.get("Question")
    print(questiontext)
    
    user_input = input("enter answer:  ")
    correct_answer = Quiz.get("answer")
    
    if user_input == correct_answer:
        score += 10 
print("Your score =", score)

# %%
import random
result = 0


quiz_questions = [
    {"QUESTION": "Is MoneyGen's core activity 'Finance'?.", "answer": "yes"},
    {"QUESTION": "Does MoneyGen offer educational resources?  ", "answer":"no"},
    {"QUESTION": "Is MoneyGen involved in gambling?  ", "answer": "yes"},
    {"QUESTION": "Can entrepreneurs benefit from MoneyGen? ", "answer": "yes"},
    {"QUESTION": "Does MoneyGen operate nationwide?  ", "answer": "no"},
    {"QUESTION": "Is MoneyGen technology-driven? ", "answer": "no"},
    {"QUESTION": "Does MoneyGen support investments? ", "answer": "yes"},
    {"QUESTION": "Are MoneyGen's services digital?  ", "answer": "yes"},
    {"QUESTION": "Does MoneyGen promote savings?   ", "answer": "no"},
    {"QUESTION":  "Is MoneyGen's platform secure?", "answer": "yes"}
    
]

question = random.sample(quiz_questions,5)
for quiz in question:   
    
    question = quiz.get("QUESTION") 
    print(question)
        
    answer_input = input("what is your answer  ").lower()
    if answer_input == quiz.get("answer"):
        result += 2

print("Your score =", result )



# JUST FOR US TO PUT IT IN A CLASS AND STORE THE RESULT

# %%
import random

result = 0

class Player:
    
    def __init__(self, name, gender, age, state):
        self.name = name
        self.gender = gender
        self.age = age
        self.state = state
        
    def Questions(self):
        global result
        quiz_questions = {
            1: "Is MoneyGen's core activity 'Finance'? Yes or No.",
            2: "Does MoneyGen offer educational resources? Yes or No.",
            3: "Is MoneyGen involved in gambling? Yes or No.",
            4: "Can entrepreneurs benefit from MoneyGen? Yes or No.",
            5: "Does MoneyGen operate nationwide? Yes or No.",
            6: "Is MoneyGen technology-driven? Yes or No.",
            7: "Does MoneyGen support investments? Yes or No.",
            8: "Are MoneyGen's services digital? Yes or No.",
            9: "Does MoneyGen promote savings? Yes or No.",
            10: "Is MoneyGen's platform secure? Yes or No."
        }
        
        question = random.sample(list(quiz_questions.keys()),10)
        for quiz in question:
            selectedquestion = quiz_questions[quiz]
            print(selectedquestion)
            answer = input("Answer: ").lower()
            if answer == "yes":
                result += 2
            else:
              
                pass


player1 = Player("John", "Male", 25, "NY")
player1.Questions()
print("Result:", result)

# %%
aliens = []
for alien_number in range(30):
    new_alien = {'color': 'green', 'points': 5, 'speed': 'slow'}
    aliens.append(new_alien)

# %%
print(aliens)
len(aliens)

# %%
# Show the first 5 aliens:
for alien in aliens[:5]:
    print(alien)
    print("...")

# %%
import random

a = [1,2,3,4,5,6,]


random.sample(a,6)

# %%
# jacob

result = 0
STOP_ANSWERING = []
class Player:
    
    def __init__(self, name, gender, age, state):
        self.name = name
        self.gender = gender
        self.age = age
        self.state = state
        
    def Questions(self):
        print('wwww')
        print("\n")
        
        quiz_questions = {
            1: "Is MoneyGen's core activity 'Finance'? Yes or No.",
            2: "Does MoneyGen offer educational resources? Yes or No.",
            3: "Is MoneyGen involved in gambling? Yes or No.",
            4: "Can entrepreneurs benefit from MoneyGen? Yes or No.",
            5: "Does MoneyGen operate nationwide? Yes or No.",
            6: "Is MoneyGen technology-driven? Yes or No.",
            7: "Does MoneyGen support investments? Yes or No.",
            8: "Are MoneyGen's services digital? Yes or No.",
            9: "Does MoneyGen promote savings? Yes or No.",
            10: "Is MoneyGen's platform secure? Yes or No."
        }
        
        for question in quiz_questions.values():
            print(question)
            
            answer = input("Enter answer: ").lower()
            if answer == "yes":
                global result
                result += 2
            elif answer != "yes":
                STOP_ANSWERING.append(1) 
                if  len(STOP_ANSWERING) == 3:
                    result = result
            
                    print(f"Your current score is: {result}")
                
                    break
                    
# Example usage
player1 = Player("John", "Male", 25, "California")
player1.Questions()

# %%
import random
Player_name = []


wrong_attempt = []
class Player:
    
    def __init__(self, name, gender, age, state):
        self.name = name
        self.gender = gender
        self.age = age
        self.state = state
        Player_name.extend((self.name, self.gender))
        
    def Questions(self):
        print('wwww')
        print("\n")

        quiz_questions = [
        {"QUESTION": "Is MoneyGen's core activity 'Finance'?.", "answer": "yes"},
        {"QUESTION": "Does MoneyGen offer educational resources?  ", "answer":"no"},
        {"QUESTION": "Is MoneyGen involved in gambling?  ", "answer": "yes"},
        {"QUESTION": "Can entrepreneurs benefit from MoneyGen? ", "answer": "yes"},
        {"QUESTION": "Does MoneyGen operate nationwide?  ", "answer": "no"},
        {"QUESTION": "Is MoneyGen technology-driven? ", "answer": "no"},
        {"QUESTION": "Does MoneyGen support investments? ", "answer": "yes"},
        {"QUESTION": "Are MoneyGen's services digital?  ", "answer": "yes"},
        {"QUESTION": "Does MoneyGen promote savings?   ", "answer": "no"},
        {"QUESTION":  "Is MoneyGen's platform secure?", "answer": "yes"}
        ]

        result = 0
        
        question = random.sample(quiz_questions,3)
        for quiz in question:   

            question = quiz.get("QUESTION") 
            print(question)

            answer_input = input("what is your answer  ").lower()
            if answer_input == quiz.get("answer"):
                result += 2
                
            elif answer_input != "answer":
                wrong_attempt.append(1) 
              
            if  len(wrong_attempt) == 3:
                result = result
                print(f"Your current score is: result")

                break
        Player_name.extend((result, ))
    
        print("Your score =", result )


player1 = Player("John", "Male", 25, "California")
player1.Questions()
player1 = Player("ade", "female", 25, "California")
player1.Questions()
Player_name

# %%
import random
Player_name = []


wrong_attempt = []
class Player:
    
    def __init__(self):
        
        print("""Welcome to the MoneyGen quiz!
        \nPrepare yourself for 10 randomly selected questions. Each question offers only two options: 'Yes' or 'No'. 
        \nEvery correct answer earns you 10 points. However, if you answer incorrectly, you'll receive 0 points for that question. 
        \nTake your time to ponder each question carefully before making your choice. Remember,
        \nif you answer three questions incorrectly, you'll be eliminated from the game.
        \nStrive for the highest score by relying on your knowledge and instincts. Good luck!""")
        self.name = input("enter your name  ")
        self.gender = input("enter your gender  ")
        self.age = input("enter your age  ")
        self.state = input("enter your state  ")
        Player_name.extend((self.name, self.gender))
        
    def Questions(self):
        
        print("\n")

        quiz_questions = [
        {"QUESTION": "Is MoneyGen's core activity 'Finance'?.", "answer": "yes"},
        {"QUESTION": "Does MoneyGen offer educational resources?  ", "answer":"no"},
        {"QUESTION": "Is MoneyGen involved in gambling?  ", "answer": "yes"},
        {"QUESTION": "Can entrepreneurs benefit from MoneyGen? ", "answer": "yes"},
        {"QUESTION": "Does MoneyGen operate nationwide?  ", "answer": "no"},
        {"QUESTION": "Is MoneyGen technology-driven? ", "answer": "no"},
        {"QUESTION": "Does MoneyGen support investments? ", "answer": "yes"},
        {"QUESTION": "Are MoneyGen's services digital?  ", "answer": "yes"},
        {"QUESTION": "Does MoneyGen promote savings?   ", "answer": "no"},
        {"QUESTION":  "Is MoneyGen's platform secure?", "answer": "yes"}
        ]

        result = 0
        
        question = random.sample(quiz_questions,3)
        for quiz in question:   

            question = quiz.get("QUESTION") 
            print(question)

            answer_input = input("what is your answer  ").lower()
            if answer_input == quiz.get("answer"):
                result += 2
                
            elif answer_input != "answer":
                wrong_attempt.append(1) 
              
            if  len(wrong_attempt) == 3:
                result = result
                print(f"Your current score is: result")

                break
        Player_name.extend((result, ))
    
        print("Your score =", result )


player1 = Player()
player1.Questions()
Player_name

# %%
print(""""Welcome to the MoneyGen quiz!

Prepare yourself for 10 randomly selected questions. Each question offers only two options: 'Yes' or 'No'. 

Every correct answer earns you 10 points. However, if you answer incorrectly, you'll receive 0 points for that question. 

Take your time to ponder each question carefully before making your choice. Remember,
\nif you answer three questions incorrectly, you'll be eliminated from the game.

Strive for the highest score by relying on your knowledge and instincts. Good luck!""")

# %%
   print("""Welcome to the MoneyGen quiz.
              \nYou're about to answer 10 random questions.\nEach with only two possible answers: 'Yes' or 'No'.
              \nEvery question is worth 10 points.
              \nPlease note that if you answer a question incorrectly, you will receive 0 points for that question.
              \nTake your time to think about each question before you make your choice
              \n If you answer three question wrong you will be eliminated from the game
              \nAim for the highest score by trusting your knowledge and instincts.\nGood luck!""")
